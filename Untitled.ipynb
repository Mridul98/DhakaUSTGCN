# %%
import pandas as pd

# %%
nov = pd.read_csv('datasets/november_final.csv')

# %%
nov
# Out:
#                                           Intersection  01_11_2019 06_00_01  \
# 0    senparaparbata(23.80581,90.36912)-mirpur10circ...                    0
# 1    mirpur10circle(23.80702,90.36851)-mainroad(23....                    0
# 2    mirpur2bs(23.80511,90.36343)-mainroad(23.8067,...                    0
# 3    mainroad(23.8067,90.36689)-mirpur2bs(23.80511,...                    0
# 4    mirpurcollegeroad(23.80339,90.36074)-mirpur2bs...                    0
# ..                                                 ...                  ...
# 149  mirpuroriginal10(23.8102909,90.3675265)-avenue...                    0
# 150  populardiagnosticcenter(4579879715)(23.8095357...                    0
# 151  mirpuroriginal10(23.8102909,90.3675265)-popula...                    0
# 152  proshikamorebusstop(23.8096296,90.3610100)-nat...                    0
# 153  proshikamorebusstop(23.8096296,90.3610100)-bra...                    0
#
# ...

# %%
dec = pd.read_csv('datasets/december_final.csv')

# %%
dec.loc[1:,:].reset_index().drop(columns = ['index']).to_csv('datasets/december_final.csv',index = False)

# %%
jan = pd.read_csv('datasets/january-2020_final.csv')

# %%
jan = jan.loc[1:,:].reset_index().drop(columns = ['index'])

# %%
jan.rename(columns={'roads':"Intersection"},inplace=True)

# %%
jan.to_csv('datasets/january-2020_final.csv',index=False)
